# %% [markdown]
# <a href="https://colab.research.google.com/github/amritsharma2409-jpg/Freelance-form/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
print(a%b)
print(a//b)
print(a**3) #exponent

print(np.sqrt(a)) #to find the sq root

print(np.power(a,5)) #for n exponent

arr = np.array([10,20,20,30,40,50])

print(np.mean(arr)) #to find the average

print(np.median(arr)) #to find the median

print(np.std(arr)) #to find the standard deviation

print(np.var(arr)) #to find the variance

print(np.max(arr)) #to find the maximum value

print(np.min(arr)) #to find the minimum value

print(np.sum(arr)) #to find the sum of all the values

print(np.cumsum(arr)) #to find the cumulative sum of all the values

print(arr.reshape(2,3))

arr1 = np.array([[1,2],[3,4]])

print(arr1.flatten())

arr2 = np.array([[1,2,3],
                 [4,5,6]])

print(arr2.T)

np.zeros((3,3))

np.ones((2,4))

np.eye(4)

np.arange(1,11)

np.random.rand(5)

np.random.randint(1,100,10)

arr3 = np.array([5,90,70,45,8,9])

print(np.sort(arr3))

arr4 = np.array([1,2,2,3,3,4])

print(np.unique(arr4))

arr5 = np.array([1,2,3])

arr6 = np.array([4,5,6])

print(np.concatenate((arr5,arr6)))

arr7 = np.array([1,2,3,4,5,6])

print(np.split(arr7,3))

arr8 = np.array([10,20,30,40,50])

print(arr[arr>25])
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [  1  32 729]
# [1 2 3]
# [0 0 0]
# [ 1  8 27]
# [1.         1.41421356 1.73205081]
# [  1  32 243]
# 28.333333333333332
# 25.0
# 13.43709624716425
# 180.55555555555557
# 50
# 10
# 170
# [ 10  30  50  80 120 170]
# [[10 20 20]
#  [30 40 50]]
# [1 2 3 4]
# [[1 4]
#  [2 5]
#  [3 6]]
# [ 5  8  9 45 70 90]
# [1 2 3 4]
# [1 2 3 4 5 6]
# [array([1, 2]), array([3, 4]), array([5, 6])]
# [30 40 50]
